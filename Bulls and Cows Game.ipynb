# %%
import random

digits = int(input("what digit number do you want to play with?\n"))

if digits == 1:
    number = random.randint(1,9)
    print ("Okay, I've decided the number. Start guessing!")
    i = 0
    running = True
    while running:
        guess = int(input("what is your guess?\n"))
        if guess != number:
            print ("0 bulls or cows, guess again\n")
            i = i + 1
        else:
            print ("Great! That's the right answer.")
            print (f"You took {i + 1 } guesses")
            again = input("Do you want to play again?(y/n)\n")
            if again == "y":
                running = True
                number = random.randint(1,9)
                i = 0
                print ("Okay, I've decided the number. Start guessing!")
            else:
                running = False
    else:
        print ("Bye-Bye")    
elif digits == 2:
    a = [1,2,3,4,5,6,7,8,9]
    n1 = random.choice(a)
    a.remove(n1)
    n10 = random.choice(a)
    number = (n10 * 10) + (n1)
  # print (f"{number}")
    print ("Okay, I've decided the number. Start guessing!\n")
    i = 0
    running = True
    while running:
        guess = int(input("what is your guess?\n"))
        g1 = guess % 10
        g2 = guess // 10
        g10 = g2 % 10
        bulls = 0
        cows = 0
        if g1 == n1:
            bulls = bulls + 1
        if g1 == n10:
            cows = cows + 1
        if g10 == n10:
            bulls = bulls + 1
        if g10 == n1:
            cows = cows + 1
        if bulls != 2:
            print (f"{guess} has {bulls} bulls and {cows} cows.\n Guess again.")
            i = i + 1
            bulls = 0
            cows = 0
        if bulls == 2:
            print ("Great! That's the right answer\n")
            print (f"You took { i + 1} guesses.") 
            again = input("Do you want to play again?(y/n)\n")
            if again == "y":
                running = True
                i = 0
                a = [1,2,3,4,5,6,7,8,9]
                n1 = random.choice(a)
                a.remove(n1)
                n10 = random.choice(a)
                number = (n10 * 10) + (n1)
               # print (f"{number}")
                print ("Okay, I've decided the number. Start guessing!\n")
            else:
                running = False
    else:
        print ("Bye-Bye")
elif digits == 3:
    a = [1,2,3,4,5,6,7,8,9]
    n1 = random.choice(a)
    a.remove(n1)
    n10 = random.choice(a)
    a.remove(n10)
    n100 = random.choice(a)
    number =  (n100 * 100) + (n10 * 10) + (n1)
   #print (f"{number}")
    print ("Okay, I've decided the number. Start guessing!\n")
    i = 0
    running = True
    while running:
        guess = int(input("what is your guess?\n"))
        g1 = guess % 10
        g2 = guess // 10
        g10 = g2 % 10
        g100 = guess // 100
        bulls = 0
        cows = 0
        if g1 == n1:
            bulls = bulls + 1
        if g1 == n10:
            cows = cows + 1
        if g1 == n100:
            cows = cows + 1    
        if g10 == n10:
            bulls = bulls + 1
        if g10 == n1:
            cows = cows + 1
        if g10 == n100:
            cows = cows + 1
        if g100 == n1:
            cows = cows + 1
        if g100 == n10:
            cows = cows + 1
        if g100 == n100:
            bulls = bulls + 1
        if bulls != 3:
            print (f"{guess} has {bulls} bulls and {cows} cows.\n Guess again.")
            i = i + 1
            bulls = 0
            cows = 0
        if bulls == 3:
            print ("Great! That's the right answer\n")
            print (f"You took {i+1} guesses")
            again = input("Do you want to play again?(y/n)\n")
            if again == "y":
                running = True
                i = 0
                a = [1,2,3,4,5,6,7,8,9]
                n1 = random.choice(a)
                a.remove(n1)
                n10 = random.choice(a)
                a.remove(n10)
                n100 = random.choice(a)
                number =  (n100 * 100) + (n10 * 10) + (n1)
              # print (f"{number}")
                print ("Okay, I've decided the number. Start guessing!\n")
            else:
                running = False
    else:
        print ("Bye-Bye")        
        
else: 
    print("the game is still under construction for that number of digits :)")
# Out:
# what digit number do you want to play with?
# 3
# Okay, I've decided the number. Start guessing!
#
# what is your guess?
# 123
# 123 has 2 bulls and 0 cows.
#  Guess again.
# what is your guess?
# 456
# 456 has 0 bulls and 0 cows.
#  Guess again.
# what is your guess?
# 381
# 381 has 0 bulls and 1 cows.
#  Guess again.
# what is your guess?
# 219
# 219 has 1 bulls and 2 cows.
#  Guess again.
# what is your guess?
# 291
# 291 has 0 bulls and 3 cows.
#  Guess again.
# what is your guess?
# 912
# 912 has 0 bulls and 3 cows.
#  Guess again.
# what is your guess?
# 129
# Great! That's the right answer
#
# You took 7 guesses
# Do you want to play again?(y/n)
# n
# Bye-Bye
